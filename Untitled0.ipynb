# %% [markdown]
# <a href="https://colab.research.google.com/github/43200755/whats/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
car=pd.read_csv('/content/cap.csv')
car.tail()
# Out:
#    | MPG  | Cylinders | Displacement | Horsepower | Weight | Acceleration | Model Year | Origin | Fuel Type |  \
# 0                                                 18
# 1                                                 15
# 2                                                 16
# 3                                                 18
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0           8         307         130         NaN        3504        12.0
# 1           8         350         165         NaN        3693        11.5
# 2           8         390         234         NaN         986        32.7
# 3           8         456         654         NaN         547        34.8
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0          70        USA        Gas
# 1          70        USA        Gas
# 2          70        USA        Gas
# 3          70        USA        Gas
